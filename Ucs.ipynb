# %% [markdown]
# <a href="https://colab.research.google.com/github/suhana0611/uniform-cost-search/blob/main/Ucs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def uniform_cost_search(graph, start, goal):
    # Priority Queue: (cost, current_node, path)
    pq = [(0, start, [start])]

    explored = set()

    while pq:
        cost, node, path = heapq.heappop(pq)

        print("Node selected:", node)
        print("Cost so far:", cost)
        print("Path:", path)
        print("----------------------")

        # If goal is reached
        if node == goal:
            print("Goal reached!")
            return cost, path

        # Skip if already explored
        if node in explored:
            continue

        explored.add(node)

        # Expand neighbours
        for neighbor, edge_cost in graph.get(node, []):
            if neighbor not in explored:
                heapq.heappush(pq, (cost + edge_cost, neighbor, path + [neighbor]))

    return float("inf"), []


# Graph from your diagram
graph = {
    'A': [('B', 2), ('C', 4)],
    'B': [('D', 3), ('E', 4)],
    'C': [('F', 5)],
    'D': [],
    'E': [('G', 3)],
    'F': [('H', 4), ('I', 6)],
    'G': [('J', 2)],
    'H': [],
    'I': [('K', 5)],
    'J': [('L', 2)],
    'K': [('M', 3)],
    'L': [],
    'M': [('N', 4)],
    'N': []
}

start = 'A'
goal = 'N'

cost, path = uniform_cost_search(graph, start, goal)

print("\nFinal Result:")
print("Optimal Cost:", cost)
print("Optimal Path:", " -> ".join(path))
# Out:
# Node selected: A
# Cost so far: 0
# Path: ['A']
# ----------------------
# Node selected: B
# Cost so far: 2
# Path: ['A', 'B']
# ----------------------
# Node selected: C
# Cost so far: 4
# Path: ['A', 'C']
# ----------------------
# Node selected: D
# Cost so far: 5
# Path: ['A', 'B', 'D']
# ----------------------
# Node selected: E
# Cost so far: 6
# Path: ['A', 'B', 'E']
# ----------------------
# Node selected: F
# Cost so far: 9
# Path: ['A', 'C', 'F']
# ----------------------
# Node selected: G
# Cost so far: 9
# Path: ['A', 'B', 'E', 'G']
# ----------------------
# Node selected: J
# Cost so far: 11
# Path: ['A', 'B', 'E', 'G', 'J']
# ----------------------
# Node selected: H
# Cost so far: 13
# Path: ['A', 'C', 'F', 'H']
# ----------------------
# Node selected: L
# Cost so far: 13
# Path: ['A', 'B', 'E', 'G', 'J', 'L']
# ----------------------
# Node selected: I
# Cost so far: 15
# Path: ['A', 'C', 'F', 'I']
# ----------------------
# Node selected: K
# Cost so far: 20
# ...
